# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data2 = np.arange(9)

# %%
#%%
# %matplotlib widget

# %%
# %matplotlib inline

# %%
plt.plot(data2)

# %% [markdown]
# ### Level 3

# %%
plt.title = "First G R A P H"

# %%
plt.xlabel("X axis")
# Out:
# Text(0.5, 0, 'X axis')

# %%
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
x = plt.plot(data2)
#plt.title("First G R A P H")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
x = [1,2,3,4,5,6,7,8]
y = [11,24,32,40,55,67,78,80]

plt.plot(x,y)

# %% [markdown]
# ### Level 3

# %%
data3 = np.arange(2,8,0.3)
plt.plot(data3,data3,"r--",data3,data3**2,"bs",data3, data3**3,"g^")
plt.savefig("plot2.png")

# %%
plt.savefig("plot.png")

# %%
#bar graphs
film = ["f1", "f2", "f3", "f4", "f5"]
awards = [2,3,5,4,5]

plt.bar(range(len(film)),awards)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Level 5

# %%
#plt.title('Award Show Stats')
film = ["f1", "f2", "f3", "f4", "f5"]
awards = [2,3,5,4,5]
plt.ylabel('Awards')
plt.xlabel("Film")
plt.xticks(range(len(film)),film)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
h = np.random.normal(150,15,239)
plt.hist(h)
# Out:
# (array([ 1.,  7., 19., 35., 54., 58., 28., 23., 13.,  1.]),
#  array([107.06440673, 115.73593506, 124.4074634 , 133.07899173,
#         141.75052007, 150.4220484 , 159.09357674, 167.76510507,
#         176.4366334 , 185.10816174, 193.77969007]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Level 7

# %%
#pie charts

x = np.array([37,27,47,17])
ch = ["first","second","third","fourth"]

plt.pie(x, labels=ch)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbea957d3a0>,
# ...
#  [Text(0.6767547496386896, 0.867181070389267, 'first'),
#   Text(-0.867181070389267, 0.6767547496386896, 'second'),
#   Text(-0.44576544540548946, -1.0056307312738837, 'third'),
#   Text(1.0056307312738837, -0.4457654454054895, 'fourth')])
